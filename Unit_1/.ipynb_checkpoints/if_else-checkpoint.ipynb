# %% [markdown]
# # 1. if statment

# %%
age = 20
if (age>=18):
    print("vote de sakte hai...:)")
# Out:
# vote de sakte hai...:)

# %% [markdown]
# # 2. if and else

# %%
age =10
if(age>=18):
    print("aap vote dene ke layak ho bhai...  :)")
else:
    print("abhi aap vote dene ke layak hai ho  :(")
# Out:
# abhi aap vote dene ke layak hai ho  :(

# %% [markdown]
# # 3. if ,elif and else

# %%
a=input("Enter number : ")
if a ==  " " or a=="":
    print("Pleace enter value :(")
elif int(a) %2==0:
    print("Number is even")
else :
    print("Number is odd")
# Out:
# Enter number :
# Pleace enter value :(
