# %%
num1=int(input("Enter Amount : "))
temp=num1

if(num1 >= 1000 and num1 < 10000):
    print("Total intrest : ",num1*0.05+temp)
    #print("Total Amount :",temp+num1)
elif(num1>10000):
    print("Total intrest : ",num1*0.10+temp)
else:
    print("Total : ",num1)
# Out:
# Enter Amount :  11000
# Total intrest :  12100.0
