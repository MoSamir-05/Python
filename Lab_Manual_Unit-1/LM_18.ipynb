# %%
num=int(input("Enter Number"))
lst=[x for x in range(50)]
# print(lst)
for vel in lst:
    print(vel)
    if vel == num:
        print("found ",end="")
        break
# Out:
# Enter Number 6
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# found

# %% [markdown]
# #####
