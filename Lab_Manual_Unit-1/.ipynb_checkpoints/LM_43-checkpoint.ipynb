# %%
num=0
while num<5:
    print("Number",num)
    num+=1
else:
    print(f"Number is now {num} or greater. Else block executed!")
# Out:
# Number 0
# Number 1
# Number 2
# Number 3
# Number 4
# Number is now {num} or greater. Else block executed!
