# %%
num=0
while num<5:
    print("Number",num)
    num+=1
else:
    print("Number is now 5 or greater. Else block executed!")
# Out:
#   Cell In[1], line 6
#     print"Number is now 5 or greater. Else block executed!"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
