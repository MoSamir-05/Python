# %%
print("Mo Samir")
num1=int(input("Enter number : "))
num2=int(input("Enter number : "))

print("add : ",num1+num2)
print("sub : ",num1-num2)
print("mul : ",num1*num2)
print("div : ",num1/num2)
print("mod : ",num1%num2)
# Out:
# Mo Samir
# Enter number :  50
# Enter number :  20
# add :  70
# sub :  30
# mul :  1000
# div :  2.5
# mod :  10
