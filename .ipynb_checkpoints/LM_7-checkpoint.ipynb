# %%
num1=int(input("Enter number : "))
num2=int(input("Enter number : "))

print("Ans : ",num1+num2)
print("Ans : ",num1-num2)
print("Ans : ",num1*num2)
print("Ans : ",num1/num2)
print("Ans : ",num1%num2)
# Out:
# Enter number :  20
# Enter number :  20
# 40
