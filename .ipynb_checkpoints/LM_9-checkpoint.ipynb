# %%
num1=input("enter number : ")
num2=input("enter number : ")
print(num1<num2,"frist number is greater than number 2")
# Out:
# enter number :  20
# enter number :  12
# False frist number is less than number 2
