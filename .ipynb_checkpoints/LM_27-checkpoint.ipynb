# %%
arr=[]
for i in range(3):
    num=int(input("Enter value : "))
    arr.append(num)
print("Large Number is : ",max(arr))
# Out:
# Enter value :  5
# Enter value :  10
# Enter value :  2
# Large Number is :  10
