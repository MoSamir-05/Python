# %%
print("Mo Samir");
prit("hello world")
# Out:
# Mo Samir
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 print("Mo Samir");
# ----> 2 prit("hello world")
#
# NameError: name 'prit' is not defined
