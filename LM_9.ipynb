# %%
num1=input("enter number : ")
num2=input("enter number : ")
if(num1 > num2 or num2<num1):
    print("Used OR opreater")
if(num1>num2 and num1!=num2):
    print("Used AND oprater")
print(not(num1>num2) )
# Out:
# enter number :  13
# enter number :  12
# Used OR opreater
# Used AND oprater
# False
