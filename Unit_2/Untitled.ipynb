# %%
from collections import Counter

# %%
lst=[1,5,7,4,5,2,3,4,5,6,1]
print (Counter(lst))
# Out:
# Counter({5: 3, 1: 2, 4: 2, 7: 1, 2: 1, 3: 1, 6: 1})

# %%
s="samir Saeed"
print(Counter(s))
# Out:
# Counter({'a': 2, 'e': 2, 's': 1, 'm': 1, 'i': 1, 'r': 1, ' ': 1, 'S': 1, 'd': 1})

# %%
c=Counter(lst)
# print(c["s"])

# %%
lst2=[1,5,7,4,5,2,3,4,5,6,1]
c2=Counter(lst2)
print(list(c2.elements()))
print(c2.most_common())
c3=Counter(a=10,b=20)
print(c3.total())
# Out:
# [1, 1, 5, 5, 5, 7, 4, 4, 2, 3, 6]
# [(5, 3), (1, 2), (4, 2), (7, 1), (2, 1), (3, 1), (6, 1)]
# 30
