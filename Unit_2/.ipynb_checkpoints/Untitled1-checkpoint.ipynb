# %%
class Hospital:
    def hospi_info(self,city="Anand"):
        print("Enter hospital info..")
        self.hname=input("Enter Hospital Name : ")
        self.city_name=input("Enter City Name : ")
class Person:
    def per_info(self):
        print("Enter person info...")
        self.p_name=input("Enter your name : ")
        self.age=input("Enter your age : ")
        self.p_gen=input("Enter your gender")
class Doctor(Hospital,Person):
    def doc_info(self):
        print("enter doctor info...")
        self.doc_spec=input("Enter your specialization :")
        self.doc_dept=input("In which department :")
    def show(self):
        print("====================")
        print()
        print("Hospital Name: ",self.hname)
        print("City Name: ",self.city_name)
        print("Person Name: ",self.p_name)
        print("person age: ",self.age)
        print("Person Gender: ",self.p_gen)
        print("Doctor Specialization: ",self.doc_spec)
        print("Doctor Department: ",self.doc_dept)

do = Doctor()
do.hospi_info()
do.per_info()
do.doc_info()
do.show()
# Out:
# Enter hospital info..
# Enter Hospital Name :  sifa
# Enter City Name :  anand
# Enter person info...
# Enter your name :  samir
# Enter your age :  22
# Enter your gender M
# enter doctor info...
# Enter your specialization : qwqwqwq
# In which department : ddfdfdf
# Hospital Name sifa
# City Name anand
# Person Name samir
# person age  22
# Person Gender M
# Doctor Specialization  qwqwqwq
# Doctor Department  ddfdfdf
