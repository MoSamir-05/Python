# %% [markdown]
# ### 14.1 Message: Write a function called display_message() that prints one sentence telling everyone what you are learning about in this chapter. Call the function, and make sure the message displays correctly.

# %%
def display_message():
    print("I am learning about functions in this chapter.")

display_message()
# Out:
# I am learning about functions in this chapter.

# %% [markdown]
# ### 14.2 Favorite Book:Write a function called favorite_book() that accepts one parameter as title. The function should print a message ,such as one of my favorite book is Alice in Wonderland.Call the function,making sure to includea book title as an argument in the function call.

# %%
def favorite_book(title):
    print(f"One of my favorite books is {title}.")

favorite_book("Alice in Wonderland")
# Out:
# One of my favorite books is Alice in Wonderland.

# %% [markdown]
# ### 14.3: T-shirt: Write a function called make_shirt() that accepts a size and the text of a message tha should be printed on the shirt.The function should print a sentence summarizing the size of the shirt and the message printed on it. Call the function once using positional arguments to a make a shirt. Call the function a second time using keyword arguments.

# %%
def make_shirt(size, message):
    print(f"The shirt size is {size} and the message printed is '{message}'.")
make_shirt("Large", "Keep Learning!")
make_shirt(size="Medium", message="Python is Fun!")
# Out:
# The shirt size is Large and the message printed is 'Keep Learning!'.
# The shirt size is Medium and the message printed is 'Python is Fun!'.

# %% [markdown]
# ### 14.4: Large Shirts: Modify the make_shirt() function so that shirts are large by default with a message that reads l love python. Make a large shirt and a medium shirt with the default message, and a shirt of any size with a diffrent message.

# %%
def make_shirt(size="Large", message="I love Python"):
    print(f"The shirt size is {size} and the message printed is '{message}'.")
make_shirt()
make_shirt(size="Medium")
make_shirt(size="Small", message="Keep Coding!")
# Out:
# The shirt size is Large and the message printed is 'I love Python'.
# The shirt size is Medium and the message printed is 'I love Python'.
# The shirt size is Small and the message printed is 'Keep Coding!'.

# %% [markdown]
# ### 14.5: Cities: Write a function called describe_city() that accepts the name of a city and its country.The function should print a simple sentence, such as Reykjavik is in Iceland. Give the parameter for the country a default value. Call your function for three different cities, at leastone of which is not in the default country.

# %%
def describe_city(city, country="India"):
    print(f"{city} is in {country}.")
describe_city("Mumbai")
describe_city("Delhi")
describe_city("Tokyo", "Japan")
# Out:
# Mumbai is in India.
# Delhi is in India.
# Tokyo is in Japan.

# %% [markdown]
# ### 14.6:City name: write a function called city_country() that takes in the name of a city and itscountry,the function should return a string formatted like this:"Santiago,Chile" call your function with at least three city-country pairs and print the value that's returned.

# %%
def city_country(city, country):
    return f"{city}, {country}"
print(city_country("Santiago", "Chile"))
print(city_country("Tokyo", "Japan"))
print(city_country("Mumbai", "India"))
# Out:
# Santiago, Chile
# Tokyo, Japan
# Mumbai, India

# %% [markdown]
# ### 14.7:Album: Write a function called make_album() that builds DICTIONARY describing music album. The function should take in an artist name and an album title, and it should return a dictionary containing these two pieces of information. Use the function to make three dictionaries representing different albums. Print each return value to show that the dictionaries are storing the album information correctly. Add an optional parameter to make_album()that allows you to store the number of tracks on an album. If the calling line includes a value for the number of tracks, add that value to the album's dictionary. Make at least one new function call that includes the number of trucks on an album.

# %%
def make_album(artist, title, tracks=None):
    album = {
        "artist": artist,
        "title": title
    }
    if tracks:
        album["tracks"] = tracks

    return album
album1 = make_album("Arijit Singh", "Soulful Melodies")
album2 = make_album("Taylor Swift", "1989")
album3 = make_album("A. R. Rahman", "Rockstar")
album_with_tracks = make_album("Linkin Park", "Meteora", tracks=13)
print(album1)
print(album2)
print(album3)
print(album_with_tracks)
# Out:
# {'artist': 'Arijit Singh', 'title': 'Soulful Melodies'}
# {'artist': 'Taylor Swift', 'title': '1989'}
# {'artist': 'A. R. Rahman', 'title': 'Rockstar'}
# {'artist': 'Linkin Park', 'title': 'Meteora', 'tracks': 13}
