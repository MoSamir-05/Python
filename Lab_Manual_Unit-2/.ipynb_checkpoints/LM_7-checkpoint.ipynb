# %% [markdown]
# ### Pizza Toppings: Write a loop that prompts the user to enter a series of pizza toppings until they enter a quit value. As they enter each topping, print a message saying you'll add that topping to their pizza.

# %%
while True:
    topping = input("Enter a pizza topping (or type 'quit' to stop): ")

    if topping.lower() == 'quit' or 'stop':
        print("Making your pizza! 🍕")
        break
    else:
        print(f"I'll add {topping} to your pizza!")
# Out:
# Enter a pizza topping (or type 'quit' to stop):  tomato
# I'll add tomato to your pizza!
# Enter a pizza topping (or type 'quit' to stop):  stop
# I'll add stop to your pizza!
# Enter a pizza topping (or type 'quit' to stop):  quit
# Making your pizza! 🍕
