# %% [markdown]
# ### 1.Write a python program to learn Python List methods

# %%
print("Mo Samir")
lst=[1,2,3,4,5,6,7,8,9]
lst2=["Mo Samir","Hujaifa","Kaif","Saqib"]
print(lst)
print(lst2)
# Out:
# Mo Samir
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# ['Mo Samir', 'Hujaifa', 'Kaif', 'Saqib']
