# %% [markdown]
# ### Write a Python Program to learn use of Python built in functions.

# %%
numbers = [10, 20, 30, 40, 50]
print("Length of list:", len(numbers))
print("Maximum value:", max(numbers))
print("Minimum value:", min(numbers))
print("Sum of numbers:", sum(numbers))
print("Sorted list:", sorted(numbers))
name = "Python"
print("Type of variable name:", type(name))
value = -25
print("Absolute value:", abs(value))
print("Rounded value of 12.678:", round(12.678, 2))
# Out:
# Length of list: 5
# Maximum value: 50
# Minimum value: 10
# Sum of numbers: 150
# Sorted list: [10, 20, 30, 40, 50]
# Type of variable name: <class 'str'>
# Absolute value: 25
# Rounded value of 12.678: 12.68
