# %% [markdown]
# ### 2.1 Guest list: If you could invite anyone,living or deceased, to dinner, who would you invite? Make a list that includes at least three people you'd like to invite to dinner.Then use your list to print a message to each person,inviting them to dinner.

# %%
lst=["Rehan","Kaif","Saqib"]
for i in lst:
    print(i,"You inviting for dinner.")
# Out:
# Rehan You inviting for dinner.
# Kaif You inviting for dinner.
# Saqib You inviting for dinner.

# %% [markdown]
# ### 2.2 changing guest list: You just hearsthat one of your guests can't make the dinner,so you need to send out a new set of invitations.You'll have to think of someone else to invite.
# ### • Start with your program from Exercise 2.1. Add a print statement at the end of your program staling the name of the guest who can't make it.
# ### • Modify your list,replacing the name of the guest who can't make it with the name of the new person you are inviting.
# ### • Print a second set of invitation message,one for each person who is still in your list.

# %%
gest1=lst[0]
print(gest1,"Will not Come")
print("New guest : ",lst[0])
lst[0]="faizal"

for i in lst:
    print(i,"You inviting for dinner.")
# Out:
# Rehan Will not Come
# New guest :  Rehan
# faizal You inviting for dinner.
# Kaif You inviting for dinner.
# Saqib You inviting for dinner.

# %% [markdown]
# ### 2.3 more guests: You just found a bigger dinner table,so now more space is available.Think of three more guests to invite to dinner.
# ### • Start with program from Exercise 2.1 or Exercise 2.2. Add a print statement to the end of your program informing people that you found a bigger dinner
# ### • Use insert() to add one new guest to the begining of your list.
# ### • Use insert() to add one new guest to the middle of your list.
# ### • Use append() to add one new guest to the end of your list.

# %%
for i in lst:
    print(i," : I went to reserve a table and was given a larger dinner table, so I am inviting additional people to join.")
lst.insert(0,"Hujaifa")
lst.append("MSD")
lst.insert(len(lst)//2,"Abdulaziz")
print(lst)
# Out:
# faizal  : I went to reserve a table and was given a larger dinner table, so I am inviting additional people to join.
# Kaif  : I went to reserve a table and was given a larger dinner table, so I am inviting additional people to join.
# Saqib  : I went to reserve a table and was given a larger dinner table, so I am inviting additional people to join.
# ['Hujaifa', 'faizal', 'Abdulaziz', 'Kaif', 'Saqib', 'MSD']

# %% [markdown]
# ### 2.4 shrinking guests list: You just found out that your new dinner table won't arrive in time for the dinner,and you have space for only two guests.
# ### • Start with your program from Exercise 2.3. Add a new line that prints a message saying that you can invite only two people for dinner.
# ### • Use pop() to remove guests from your list one at a time until only two names remain in your list.Each time you pop a name from your list,print a message to that person letting them know you're sorry you can't invite them to dinner.
# ### • Print a message to each of the two people still on your list,letting them know they're still invited.
# ### • Use del to remove the last two names from your list,so you have an empty list.Print your list to make sure you actually have an empty list at the end of your program.

# %%
lst=["Samir","Rehan","kaif","Saqib"]
for i in lst:
    print(i,"The table I was supposed to get is no longer available, so I have to cancel the dinner. The table that is now available can accommodate only two people.")
while len(lst)>2:
    isremove=lst.pop()
    print(f"Dear {isremove} ")
    print("I am sorry ,but i no longer have space for you")
print("Good news for remaining guest that ware not about to attend the dinner to night")
new_lst=[]
for i in lst:
    print(f"Dear {i}")
    print("Good news You are come to night party")
    new_lst.append(i)
del new_lst[0]
del new_lst[0]

print(new_lst)

print("List is now empty"if not new_lst else "List stil has geust")
# Out:
# Samir The table I was supposed to get is no longer available, so I have to cancel the dinner. The table that is now available can accommodate only two people.
# Rehan The table I was supposed to get is no longer available, so I have to cancel the dinner. The table that is now available can accommodate only two people.
# kaif The table I was supposed to get is no longer available, so I have to cancel the dinner. The table that is now available can accommodate only two people.
# Saqib The table I was supposed to get is no longer available, so I have to cancel the dinner. The table that is now available can accommodate only two people.
# Dear Saqib
# I am sorry ,but i no longer have space for you
# Dear kaif
# I am sorry ,but i no longer have space for you
# Good news for remaining guest that ware not about to attend the dinner to night
# Dear Samir
# Good news You are come to night party
# Dear Rehan
# Good news You are come to night party
# []
# List is now empty

# %% [markdown]
# ### 2.5 seeing the world: Think of at least five places in the world you'd like to visit.
# ### • Store the location in a list.Make sure the list is not in alphabetical order.
# ### • Print your list in its orignal order.Don't worry about printing the list neatly,just print it as a raw Python list.
# ### • Use sort() to print your list in alphabetical order without modifying the actual list.
# ### • Show that your list is still in its original order by printing it.
# ### • Use sort() to print your list in reverse alphabetical order without changing the order of the original list.
# ### • Show that your list is still in its original order by printing it again.
# ### • Use reverse() to change the order of youe list.Print the list to show that its order has changed.
# ### • Use reverse() to change the order of youe list again.Print the list to show its back to it’s original order.
# ### • Use sort() to change your list so it's stored in alphabetical order.Print the list to show that its order has been changed.
# ### • Use sort() to change your list so it's stored in reverse alphabetical order. Print the list to show that its order has been changed.

# %%
fav_list=["USA","UAE","Thailand","Tokyo","Toyata"]
print(fav_list)
sor=sorted(fav_list)
print(sor)
print("Original list",fav_list)
sor_rev=sorted(fav_list,reverse=True)
print(sor_rev)
fav_list.reverse()
print(fav_list)
fav_list.reverse()
print(fav_list)
fav_list.sort()
print(fav_list)
fav_list.sort(reverse=True)
print(fav_list)
# Out:
# ['USA', 'UAE', 'Thailand', 'Tokyo', 'Toyata']
# ['Thailand', 'Tokyo', 'Toyata', 'UAE', 'USA']
# Original list ['USA', 'UAE', 'Thailand', 'Tokyo', 'Toyata']
# ['USA', 'UAE', 'Toyata', 'Tokyo', 'Thailand']
# ['Toyata', 'Tokyo', 'Thailand', 'UAE', 'USA']
# ['USA', 'UAE', 'Thailand', 'Tokyo', 'Toyata']
# ['Thailand', 'Tokyo', 'Toyata', 'UAE', 'USA']
# ['USA', 'UAE', 'Toyata', 'Tokyo', 'Thailand']

# %% [markdown]
# ### 2.6 dinner guests: Working with one of the programms from exercises 2.1 through 2.4. use len() to print message indicating the number of people you are inviting to dinner.

# %%
length=len(new_lst)
print(length)
# Out:
# 0
